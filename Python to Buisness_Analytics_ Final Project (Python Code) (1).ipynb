# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import calendar
import matplotlib.pyplot as plt


df = pd.read_csv(r"C:\Users\jorda\OneDrive\Product_And_Order_Data.csv")
df = df.drop(columns=['column1','Order_Customer_Id.1','Order_City','Order_Id.1','Order_Item_Cardprod_Id.1','column1.1','column1.2','Category_Id','Category_Id.1','Product_Card_Id.1','Product_Category_Id.1','Department_Id','Order_Customer_Id','Order_Item_Cardprod_Id','Order_Item_Id','Order_Item_Id.1','Product_Card_Id','Product_Category_Id','Order_Status','Order_Zipcode','Type','Customer_Id', 'Order_Id','Product_Description','Product_Image','Product_Status'])

# %%
df
# Out:
#           Category_Name                               Product_Name  \
# 0       Women's Apparel       Nike Men's Dri-FIT Victory Golf Polo
# 1       Women's Apparel       Nike Men's Dri-FIT Victory Golf Polo
# 2       Women's Apparel       Nike Men's Dri-FIT Victory Golf Polo
# 3       Women's Apparel       Nike Men's Dri-FIT Victory Golf Polo
# 4       Women's Apparel       Nike Men's Dri-FIT Victory Golf Polo
# ...                 ...                                        ...
# 639304   Men's Footwear    Nike Men's CJ Elite 2 TD Football Cleat
# 639305          Fishing  Field & Stream Sportsman 16 Gun Fire Safe
# 639306          Fishing  Field & Stream Sportsman 16 Gun Fire Safe
# 639307          Fishing  Field & Stream Sportsman 16 Gun Fire Safe
# 639308          Fishing  Field & Stream Sportsman 16 Gun Fire Safe
#
#         Product_Price  Benefit_per_order Order_Country  \
# 0           50.000000        -146.600006        Brasil
# 1           50.000000          55.000000        Brasil
# 2           50.000000           3.700000        Brasil
# 3           50.000000         130.490005        Brasil
# 4           50.000000          46.270000        Brasil
# ...               ...                ...           ...
# 639304     129.990005          94.080002        Brasil
# 639305     399.980011          75.430000        Brasil
# 639306     399.980011           9.390000        Brasil
# 639307     399.980011          51.160000        Brasil
# 639308     399.980011          94.080002        Brasil
#
#               order_date_DateOrders  Order_Item_Discount  \
# 0       2015-05-27 02:56:00.0000000             0.000000
# 1       2015-05-27 02:56:00.0000000            50.000000
# 2       2015-05-27 02:56:00.0000000             8.000000
# 3       2015-05-27 02:56:00.0000000            52.000000
# 4       2015-05-27 02:56:00.0000000            23.990000
# ...                             ...                  ...
# 639304  2015-05-26 22:02:00.0000000            64.000000
# 639305  2015-05-26 22:02:00.0000000            16.799999
# 639306  2015-05-26 22:02:00.0000000             5.200000
# 639307  2015-05-26 22:02:00.0000000            23.400000
# 639308  2015-05-26 22:02:00.0000000            64.000000
#
#         Order_Item_Discount_Rate  Order_Item_Product_Price  \
# 0                           0.00                 50.000000
# 1                           0.20                 50.000000
# 2                           0.16                 50.000000
# 3                           0.13                399.980011
# 4                           0.12                 49.980000
# ...                          ...                       ...
# 639304                      0.16                399.980011
# 639305                      0.07                 59.990002
# 639306                      0.13                 39.990002
# 639307                      0.18                129.990005
# 639308                      0.16                399.980011
#
#         Order_Item_Profit_Ratio  Order_Item_Quantity  Order_Item_Total  \
# 0                         -0.73                    4        200.000000
# 1                          0.28                    5        200.000000
# 2                          0.09                    1         42.000000
# 3                          0.38                    1        347.980011
# 4                          0.26                    4        175.929993
# ...                         ...                  ...               ...
# 639304                     0.28                    1        335.980011
# 639305                     0.34                    4        223.160004
# 639306                     0.27                    1         34.790001
# 639307                     0.48                    1        106.589996
# 639308                     0.28                    1        335.980011
#
#         Order_Profit_Per_Order   Order_Region     Order_State       Sales
# 0                  -146.600006  South America         Marañón  200.000000
# 1                    55.000000  South America         Marañón  250.000000
# 2                     3.700000  South America         Marañón   50.000000
# 3                   130.490005  South America         Marañón  399.980011
# 4                    46.270000  South America         Marañón  199.919998
# ...                        ...            ...             ...         ...
# 639304               94.080002  South America  Santa Catarina  399.980011
# 639305               75.430000  South America  Santa Catarina  239.960007
# 639306                9.390000  South America  Santa Catarina   39.990002
# 639307               51.160000  South America  Santa Catarina  129.990005
# 639308               94.080002  South America  Santa Catarina  399.980011
#
# [639309 rows x 16 columns]

# %%
region_orders= df[['Order_Region','Order_Profit_Per_Order']]
region_profits = region_orders.groupby(['Order_Region'])['Order_Profit_Per_Order'].sum()
series_object = pd.Series(region_profits)
african_regions = ['Central Africa', 'East Africa', 'North Africa', 'Southern Africa', 'West Africa']
african_series = series_object[series_object.index.isin(african_regions)]

# %%
african_series
# Out:
# Order_Region
# Central Africa     125347.489816
# East Africa        158075.589743
# North Africa       244148.180113
# Southern Africa    109262.380269
# West Africa        297906.270116
# Name: Order_Profit_Per_Order, dtype: float64

# %%
plt.pie(african_series.values,colors = ['gold', 'mediumvioletred', 'lightskyblue', 'red', 'darkgreen'])
plt.legend(labels=african_series.index,title = 'Region',loc="right",bbox_to_anchor=(1, 0, 0.5, 1))
plt.title('Profits by African Region')
plt.tight_layout()
plt.show()

# %%
x = range(len(african_series))
plt.bar(x, african_series.values, color=['gold', 'mediumvioletred', 'lightskyblue', 'red', 'darkgreen'])
plt.xticks(x, african_series.index, rotation=90)  # Assuming the index contains region names
plt.xlabel('Region')
plt.ylabel('Profits')
# Out:
# Text(0, 0.5, 'Profits')

# %%
product_type = df[['Category_Name','Order_Item_Quantity']]
total_product_quantity = product_type.groupby(['Category_Name'])['Order_Item_Quantity'].sum()
total_product_quantity= total_product_quantity.sort_values(ascending=False)

# %%
total_product_quantity
# Out:
# Category_Name
# Cleats                  216202
# Women's Apparel         185351
# Indoor/Outdoor Games    171099
# Men's Footwear          151921
# Fishing                 118052
# Cardio Equipment        110398
# Water Sports            105236
# Shop By Sport            95982
# Camping & Hiking         93412
# Electronics              28101
# Accessories              15571
# Golf Balls               13053
# Girls' Apparel           10542
# Golf Gloves               9047
# Trade-In                  8407
# Baseball & Softball       5570
# Hockey                    5271
# Golf Shoes                4390
# Hunting & Shooting        4021
# Boxing & MMA              3763
# Golf Apparel              3521
# Tennis & Racquet          3042
# Lacrosse                  2925
# Kids' Golf Clubs          2754
# Fitness Accessories       2591
# Men's Golf Clubs          1916
# Women's Golf Clubs        1386
# Soccer                    1074
# Video Games                838
# Strength Training          720
# Children's Clothing        652
# Women's Clothing           650
# Cameras                    592
# As Seen on  TV!            574
# Toys                       529
# Pet Supplies               492
# Crafts                     484
# Garden                     484
# DVDs                       483
# Computers                  442
# Music                      434
# Consumer Electronics       431
# Basketball                 424
# Golf Bags & Carts          417
# Books                      405
# Health and Beauty          362
# Sporting Goods             357
# CDs                        271
# Men's Clothing             208
# Baby                       207
# Name: Order_Item_Quantity, dtype: int64

# %%
plt.figure().set_figwidth(15)
plt.bar(total_product_quantity.index, total_product_quantity.values)
plt.title("Product Type by Quantity")
plt.ylabel('Quantity')
plt.xticks(rotation=90)
plt.tick_params(axis='x', which='major', labelsize=12)
plt.xlabel('Product Type')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df[['Order_Date','Order_Time']] = df['order_date_DateOrders'].str.split(' ',expand=True)
df[['Order_Year','Order_Month','Order_Day']] = df['Order_Date'].str.split('-',expand=True)
orders_dates = df[['Order_Date','Order_Year','Order_Month','Order_Day']]

# %%
orders_dates
# Out:
#         Order_Date Order_Year Order_Month Order_Day
# 0       2015-05-27       2015          05        27
# 1       2015-05-27       2015          05        27
# 2       2015-05-27       2015          05        27
# 3       2015-05-27       2015          05        27
# 4       2015-05-27       2015          05        27
# ...            ...        ...         ...       ...
# 639304  2015-05-26       2015          05        26
# 639305  2015-05-26       2015          05        26
# 639306  2015-05-26       2015          05        26
# 639307  2015-05-26       2015          05        26
# 639308  2015-05-26       2015          05        26
#
# [639309 rows x 4 columns]

# %%
order_count_by_date = orders_dates.groupby(['Order_Date'])['Order_Date'].value_counts()
order_count_by_date= order_count_by_date.sort_index()
df2 = pd.DataFrame({'Date':order_count_by_date.index, 'Order_Count':order_count_by_date.values})
df2[['Order_Year','Order_Month','Order_Day']] = df2['Date'].str.split('-',expand=True)

# %%
df2
# Out:
#             Date  Order_Count Order_Year Order_Month Order_Day
# 0     2015-01-01          606       2015          01        01
# 1     2015-01-02          552       2015          01        02
# 2     2015-01-03          655       2015          01        03
# 3     2015-01-04          709       2015          01        04
# 4     2015-01-05          558       2015          01        05
# ...          ...          ...        ...         ...       ...
# 1122  2018-01-27           68       2018          01        27
# 1123  2018-01-28           69       2018          01        28
# 1124  2018-01-29           68       2018          01        29
# 1125  2018-01-30           69       2018          01        30
# 1126  2018-01-31           68       2018          01        31
#
# [1127 rows x 5 columns]

# %%
order_count_by_year = df2.groupby(['Order_Year'])['Order_Count'].sum()
order_count_by_year = order_count_by_year.drop('2018')

# %%
order_count_by_year
# Out:
# Order_Year
# 2015    229256
# 2016    229076
# 2017    178854
# Name: Order_Count, dtype: int64

# %%
plt.bar(order_count_by_year.index, order_count_by_year.values)
plt.title("Yearly Total Order Count")
plt.ylabel('Order Count')
plt.xlabel('Year')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df3 = df2.drop(df2[df2['Order_Year'] == '2016'].index)
df3 = df3.drop(df3[df3['Order_Year'] == '2017'].index)
df3 = df3.drop(df3[df3['Order_Year'] == '2018'].index)
df4 = df2.drop(df2[df2['Order_Year'] == '2015'].index)
df4 = df4.drop(df4[df4['Order_Year'] == '2017'].index)
df4 = df4.drop(df4[df4['Order_Year'] == '2018'].index)
df5 = df2.drop(df2[df2['Order_Year'] == '2015'].index)
df5 = df5.drop(df5[df5['Order_Year'] == '2016'].index)
df5 = df5.drop(df5[df5['Order_Year'] == '2018'].index)

# %%
order_count_2015 = df3.groupby(['Order_Month'])['Order_Count'].sum()
order_count_2016 = df4.groupby(['Order_Month'])['Order_Count'].sum()
order_count_2017 = df5.groupby(['Order_Month'])['Order_Count'].sum()

# %%
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.plot(months, order_count_2015.values)
plt.plot(months, order_count_2016.values)
plt.plot(months, order_count_2017.values)
plt.xlabel("Month")
plt.ylabel("Order Count")
plt.title("Monthly Orders Placed")  
plt.show()

# %%
Y2015 = df[['Category_Name','Order_Item_Quantity','Order_Year','Order_Month','Order_Day']]
Y2015 = Y2015.drop(Y2015[Y2015['Order_Year'] == '2016'].index)
Y2015 = Y2015.drop(Y2015[Y2015['Order_Year'] == '2017'].index)
Y2015 = Y2015.drop(Y2015[Y2015['Order_Year'] == '2018'].index)
Y2015
# Out:
#           Category_Name  Order_Item_Quantity Order_Year Order_Month Order_Day
# 0       Women's Apparel                    4       2015          05        27
# 1       Women's Apparel                    5       2015          05        27
# 2       Women's Apparel                    1       2015          05        27
# 3       Women's Apparel                    1       2015          05        27
# 4       Women's Apparel                    4       2015          05        27
# ...                 ...                  ...        ...         ...       ...
# 639304   Men's Footwear                    1       2015          05        26
# 639305          Fishing                    4       2015          05        26
# 639306          Fishing                    1       2015          05        26
# 639307          Fishing                    1       2015          05        26
# 639308          Fishing                    1       2015          05        26
#
# [229256 rows x 5 columns]

# %%
monthly_product_quantity = Y2015.groupby(['Order_Month','Category_Name'])['Order_Item_Quantity'].sum()
monthly_product_quantity = monthly_product_quantity.groupby(level='Order_Month', group_keys=False).apply(lambda x: x.sort_values(ascending=False).head(5))
monthly_product_quantity = monthly_product_quantity.to_frame()

# %%
monthly_product_quantity
# Out:
#                                   Order_Item_Quantity
# Order_Month Category_Name
# 01          Cleats                               7099
#             Indoor/Outdoor Games                 5559
#             Women's Apparel                      5526
#             Men's Footwear                       4232
#             Fishing                              3736
# 02          Cleats                               5727
#             Women's Apparel                      5254
#             Indoor/Outdoor Games                 4655
#             Men's Footwear                       4397
#             Fishing                              3049
# 03          Cleats                               6965
#             Women's Apparel                      6054
#             Indoor/Outdoor Games                 5804
#             Men's Footwear                       4241
#             Fishing                              3736
# 04          Cleats                               6313
#             Women's Apparel                      6032
#             Indoor/Outdoor Games                 5217
#             Men's Footwear                       4557
#             Fishing                              3524
# 05          Cleats                               6623
#             Women's Apparel                      5776
#             Indoor/Outdoor Games                 5339
#             Men's Footwear                       4337
#             Cardio Equipment                     4115
# 06          Cleats                               6314
#             Women's Apparel                      5132
#             Indoor/Outdoor Games                 4949
#             Men's Footwear                       4495
#             Cardio Equipment                     3881
# 07          Cleats                               6681
#             Women's Apparel                      6425
#             Indoor/Outdoor Games                 5451
#             Men's Footwear                       4543
#             Fishing                              3599
# 08          Cleats                               7081
#             Women's Apparel                      5734
#             Indoor/Outdoor Games                 4620
#             Men's Footwear                       4578
#             Cardio Equipment                     3495
# 09          Cleats                               6427
#             Women's Apparel                      5498
#             Indoor/Outdoor Games                 5179
#             Men's Footwear                       4804
#             Cardio Equipment                     3379
# 10          Cleats                               6401
#             Women's Apparel                      5783
#             Indoor/Outdoor Games                 5230
#             Men's Footwear                       4650
#             Cardio Equipment                     3663
# 11          Cleats                               6482
#             Indoor/Outdoor Games                 5338
#             Women's Apparel                      5123
#             Men's Footwear                       4568
#             Fishing                              3708
# 12          Cleats                               6614
#             Indoor/Outdoor Games                 5558
#             Women's Apparel                      5474
#             Men's Footwear                       4891
#             Fishing                              3818

# %%
sns.scatterplot(data=monthly_product_quantity, x='Order_Month', y='Order_Item_Quantity', hue='Category_Name', palette='tab10', s=100)
plt.xlabel("Month")
plt.ylabel("Order Count")
plt.title("2015 Top 5 Monthly Products Ordered")
plt.legend(title='Product Category', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
